# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns
import codecs, json, time, re, tweepy

# %%
with codecs.open('../Scrape_Twitter_for_Tweets/twitterscraper/netneutrality.json', 'r', 'utf-8') as f:
    tweets = json.load(f, encoding='utf-8')

# %%
df = pd.DataFrame(tweets)
df
# Out:
#                                          fullname                  id likes  \
# 0                                              RH  940732847924629511     4
# 1                                        🍍Kevin 🍍  940732848604139526     0
# 2                                  Kristin Shafel  940732850105495553     0
# 3                                        gracie 🌻  940732855344394240     0
# 4                              Protest in the USA  940732863040831489    49
# 5                                           Jamie  940732870070558720     0
# 6                                             nym  940732872822001664     0
# 7                                       Ravenhowl  940732874562719745     0
# 8                                      Ginger Kay  940732878035365888     0
# 9                                 Margaret Arnett  940732883530059778     0
# 10                         Text BATTLE to 384-387  940732895311867904    11
# ...

# %%
# Parsing timestamp into Date & Time columns - T is the Time component in ISO 8601 
for time in df["timestamp"]:
    for i in np.arange(len(df["timestamp"])):
        df["Date(UTC)"] = df["timestamp"][i].split("T")[0]
        df["Time(UTC)"] = df["timestamp"][i].split("T")[1]
        
df

# %%
np.arange(3)
# Out:
# array([0, 1, 2])

# %%
df["timestamp"][0].split("T") 
for time in df["timestamp"]:
    df["datetime_object"] = datetime.strptime(time, '%b %d %Y %I:%M%p')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-63e547910dc4> in <module>()
#       1 df["timestamp"][0]
#       2 for time in df["timestamp"]:
# ----> 3     df["datetime_object"] = datetime.strptime(time, '%b %d %Y %I:%M%p')
#
# ~/anaconda3/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# ~/anaconda3/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     360     if not found:
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
# ...
