# %%
#import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import tweepy
import seaborn as sns
import time

# %%
# import vade
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys
consumer_key = "5G5qJbC2JnSOK7X0LuyBgdl1s"
consumer_secret = "SI1R97cioH9us6qzbV8lLfCdVzColdV7zZGdvDzivyJ8TD4JUx"
access_token = "358992061-DyzdZ3Ah4dayoVnmXTHH2ML2PguUVrGdSGNfSUgf"
access_token_secret = "dRGIIiZEkbfCuOME3uInFlyUUWixnjzHgzAeRVm79Y0eB"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
news_accounts = ['Jimcramer','benbernanke','FT','Business','themotleyfool','wsj','DougKass']

# %%
public_tweet = api.user_timeline(news_accounts[0])

# %%
print(json.dumps(public_tweet[11], indent = 4, sort_keys= True, separators=(',', ': ')))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Dec 14 00:19:59 +0000 2017",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "twitter.com/SCadick/status\u2026",
#                 "expanded_url": "https://twitter.com/SCadick/status/941099631357939712",
#                 "indices": [
#                     24,
#                     47
#                 ],
#                 "url": "https://t.co/18PVfcxyt5"
#             }
#         ],
#         "user_mentions": []
#     },
#     "favorite_count": 16,
#     "favorited": false,
#     "geo": null,
#     "id": 941100417949237248,
#     "id_str": "941100417949237248",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": true,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "quoted_status": {
#         "contributors": null,
#         "coordinates": null,
#         "created_at": "Thu Dec 14 00:16:51 +0000 2017",
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "urls": [],
#             "user_mentions": [
#                 {
#                     "id": 14216123,
#                     "id_str": "14216123",
#                     "indices": [
#                         0,
#                         10
#                     ],
#                     "name": "Jim Cramer",
#                     "screen_name": "jimcramer"
#                 }
#             ]
#         },
#         "favorite_count": 2,
#         "favorited": false,
#         "geo": null,
#         "id": 941099631357939712,
#         "id_str": "941099631357939712",
#         "in_reply_to_screen_name": "jimcramer",
#         "in_reply_to_status_id": 941095500400513024,
#         "in_reply_to_status_id_str": "941095500400513024",
#         "in_reply_to_user_id": 14216123,
#         "in_reply_to_user_id_str": "14216123",
#         "is_quote_status": false,
#         "lang": "en",
#         "place": null,
#         "retweet_count": 1,
#         "retweeted": false,
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "text": "@jimcramer Crypto currency reminds me of golkdfingers plot in the James Bond classic",
#         "truncated": false,
#         "user": {
#             "contributors_enabled": false,
#             "created_at": "Wed Apr 08 18:04:40 +0000 2015",
#             "default_profile": true,
#             "default_profile_image": false,
#             "description": "30 years USMC fighter pilot, Oracle PL/SQL Developer, hunter, fisherman, pilot , chef, Asia Correspondent, Texan,Farmer. Wharton MBA,Harvard PhD EE",
#             "entities": {
#                 "description": {
#                     "urls": []
#                 },
#                 "url": {
#                     "urls": [
#                         {
#                             "display_url": "taipantech.com",
#                             "expanded_url": "http://www.taipantech.com",
#                             "indices": [
#                                 0,
#                                 22
#                             ],
#                             "url": "http://t.co/73Y2OcG3X8"
#                         }
#                     ]
#                 }
#             },
#             "favourites_count": 665,
#             "follow_request_sent": false,
#             "followers_count": 475,
#             "following": false,
#             "friends_count": 1426,
#             "geo_enabled": true,
#             "has_extended_profile": true,
#             "id": 3145220527,
#             "id_str": "3145220527",
#             "is_translation_enabled": false,
#             "is_translator": false,
#             "lang": "en",
#             "listed_count": 29,
#             "location": "Singapore",
#             "name": "Col. Cadick USMC Ret",
#             "notifications": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/3145220527/1465428868",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/870767801991970816/QhSVQfeE_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/870767801991970816/QhSVQfeE_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "protected": false,
#             "screen_name": "SCadick",
#             "statuses_count": 6640,
#             "time_zone": null,
#             "translator_type": "none",
#             "url": "http://t.co/73Y2OcG3X8",
#             "utc_offset": null,
#             "verified": false
#         }
#     },
#     "quoted_status_id": 941099631357939712,
#     "quoted_status_id_str": "941099631357939712",
#     "retweet_count": 2,
#     "retweeted": false,
#     "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#     "text": "Operation Grand Slam!!! https://t.co/18PVfcxyt5",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Tue Mar 25 15:16:57 +0000 2008",
#         "default_profile": false,
#         "default_profile_image": false,
#         "description": "I am founder of @TheStreet & I run charitable trust portfolio Action Alerts PLUS. I also host @MadMoneyOnCNBC & blog daily on https://t.co/sGTJX6GWO2. Booyah!",
#         "entities": {
#             "description": {
#                 "urls": [
#                     {
#                         "display_url": "RealMoney.com",
#                         "expanded_url": "http://RealMoney.com",
#                         "indices": [
#                             126,
#                             149
#                         ],
#                         "url": "https://t.co/sGTJX6GWO2"
#                     }
#                 ]
#             },
#             "url": {
#                 "urls": [
#                     {
#                         "display_url": "facebook.com/jimcramerica",
#                         "expanded_url": "http://facebook.com/jimcramerica",
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "url": "https://t.co/2BZiRwwQja"
#                     }
#                 ]
#             }
#         },
#         "favourites_count": 12935,
#         "follow_request_sent": false,
#         "followers_count": 1053718,
#         "following": false,
#         "friends_count": 521,
#         "geo_enabled": true,
#         "has_extended_profile": false,
#         "id": 14216123,
#         "id_str": "14216123",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 11738,
#         "location": "New York City",
#         "name": "Jim Cramer",
#         "notifications": false,
#         "profile_background_color": "000000",
#         "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/759729885/dbd24c66c3f173237d8d3be45306ce71.jpeg",
#         "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/759729885/dbd24c66c3f173237d8d3be45306ce71.jpeg",
#         "profile_background_tile": true,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/14216123/1407529702",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/451344676914593792/8lV96m2l_normal.jpeg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/451344676914593792/8lV96m2l_normal.jpeg",
#         "profile_link_color": "1B8DBF",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "C7C7C7",
#         "profile_text_color": "000000",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "jimcramer",
#         "statuses_count": 82256,
#         "time_zone": "Quito",
#         "translator_type": "none",
#         "url": "https://t.co/2BZiRwwQja",
#         "utc_offset": -18000,
#         "verified": true
#     }
# }

# %%
counter = 1
sentiment = []

# %%
for account in news_accounts:
    counter = 1 
    for x in range (20):
        account_tweets = api.user_timeline(account,page = x+1)
        
        for tweet in account_tweets:
            compound = analyzer.polarity_scores(tweet["text"])["compound"]
            pos = analyzer.polarity_scores(tweet["text"])["pos"]
            neu = analyzer.polarity_scores(tweet["text"])["neu"]
            neg = analyzer.polarity_scores(tweet["text"])["neg"]
            tweets_ago = counter
            
            
           
            
            sentiment.append({'User':account,
                           "Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           'Followers':tweet['user']['followers_count'],
                           "Tweets Ago": counter})
            
            counter = counter + 1

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-b6d1524100ee> in <module>()
# ----> 1 public_tweet['user']['followers_count']
#
# TypeError: list indices must be integers or slices, not str

# %%
sentiment_tweets = pd.DataFrame.from_dict(sentiment)
sentiment_tweets.head(50)
# Out:
#     Compound                            Date  Followers  Negative  Neutral  \
# 0     0.5707  Thu Dec 14 03:36:49 +0000 2017    1053721     0.749    0.000
# 1     0.0000  Thu Dec 14 03:36:20 +0000 2017    1053721     1.000    0.000
# 2     0.0000  Thu Dec 14 03:35:52 +0000 2017    1053721     1.000    0.000
# 3     0.6369  Thu Dec 14 03:34:32 +0000 2017    1053721     0.846    0.000
# 4     0.3818  Thu Dec 14 03:33:00 +0000 2017    1053721     0.687    0.107
# 5     0.0000  Thu Dec 14 03:32:28 +0000 2017    1053721     1.000    0.000
# 6     0.7901  Thu Dec 14 03:29:09 +0000 2017    1053721     0.561    0.069
# 7     0.1531  Thu Dec 14 00:38:38 +0000 2017    1053721     0.756    0.105
# 8     0.6597  Thu Dec 14 00:21:53 +0000 2017    1053721     0.779    0.000
# 9     0.6369  Thu Dec 14 00:21:34 +0000 2017    1053721     0.851    0.000
# 10    0.0000  Thu Dec 14 00:21:06 +0000 2017    1053721     1.000    0.000
# 11    0.3129  Thu Dec 14 00:19:59 +0000 2017    1053721     0.236    0.307
# 12    0.3612  Thu Dec 14 00:01:35 +0000 2017    1053721     0.828    0.000
# 13   -0.6114  Thu Dec 14 00:01:08 +0000 2017    1053721     0.286    0.714
# 14    0.2732  Thu Dec 14 00:00:45 +0000 2017    1053721     0.766    0.094
# 15    0.5768  Thu Dec 14 00:00:26 +0000 2017    1053721     0.758    0.000
# 16    0.2023  Wed Dec 13 23:48:11 +0000 2017    1053721     0.614    0.158
# 17    0.0000  Wed Dec 13 22:39:06 +0000 2017    1053721     1.000    0.000
# 18   -0.8221  Wed Dec 13 21:33:14 +0000 2017    1053721     0.610    0.390
# 19    0.0000  Wed Dec 13 21:33:04 +0000 2017    1053721     1.000    0.000
# 20    0.0000  Wed Dec 13 21:31:37 +0000 2017    1053721     1.000    0.000
# 21   -0.5423  Wed Dec 13 20:50:13 +0000 2017    1053721     0.774    0.226
# 22    0.4404  Wed Dec 13 20:45:19 +0000 2017    1053721     0.884    0.000
# 23    0.0000  Wed Dec 13 20:44:38 +0000 2017    1053721     1.000    0.000
# 24    0.8442  Wed Dec 13 14:56:23 +0000 2017    1053721     0.637    0.000
# 25    0.8533  Wed Dec 13 14:56:12 +0000 2017    1053721     0.517    0.000
# 26    0.0000  Wed Dec 13 14:55:23 +0000 2017    1053721     1.000    0.000
# 27    0.6369  Wed Dec 13 14:45:47 +0000 2017    1053721     0.488    0.000
# 28    0.0000  Wed Dec 13 14:43:35 +0000 2017    1053721     1.000    0.000
# 29    0.0000  Wed Dec 13 14:43:02 +0000 2017    1053721     1.000    0.000
# 30    0.4767  Wed Dec 13 14:20:07 +0000 2017    1053721     0.814    0.000
# 31    0.6884  Wed Dec 13 14:16:56 +0000 2017    1053721     0.176    0.000
# 32    0.4019  Wed Dec 13 14:16:40 +0000 2017    1053721     0.828    0.000
# 33    0.0000  Wed Dec 13 14:16:32 +0000 2017    1053721     1.000    0.000
# 34    0.0000  Wed Dec 13 14:16:24 +0000 2017    1053721     1.000    0.000
# 35    0.0000  Wed Dec 13 09:44:27 +0000 2017    1053721     1.000    0.000
# 36    0.6597  Wed Dec 13 09:44:06 +0000 2017    1053721     0.787    0.000
# 37    0.0000  Wed Dec 13 09:42:27 +0000 2017    1053721     1.000    0.000
# 38    0.0000  Wed Dec 13 09:42:03 +0000 2017    1053721     1.000    0.000
# 39    0.3612  Wed Dec 13 00:28:34 +0000 2017    1053721     0.815    0.000
# 40   -0.5848  Wed Dec 13 00:20:19 +0000 2017    1053721     0.442    0.558
# 41    0.0000  Wed Dec 13 00:19:51 +0000 2017    1053721     1.000    0.000
# 42    0.2960  Wed Dec 13 00:17:27 +0000 2017    1053721     0.845    0.000
# 43    0.0000  Tue Dec 12 20:29:17 +0000 2017    1053721     1.000    0.000
# 44   -0.6996  Tue Dec 12 20:28:18 +0000 2017    1053721     0.692    0.308
# 45    0.0000  Tue Dec 12 20:26:20 +0000 2017    1053721     1.000    0.000
# 46    0.0000  Tue Dec 12 20:09:34 +0000 2017    1053721     1.000    0.000
# 47    0.0000  Tue Dec 12 20:04:03 +0000 2017    1053721     1.000    0.000
# 48   -0.1027  Tue Dec 12 20:03:10 +0000 2017    1053721     0.851    0.149
# 49   -0.6369  Tue Dec 12 19:59:57 +0000 2017    1053721     0.802    0.198
#
#     Positive  Tweets Ago       User
# 0      0.251           1  Jimcramer
# 1      0.000           2  Jimcramer
# 2      0.000           3  Jimcramer
# 3      0.154           4  Jimcramer
# 4      0.206           5  Jimcramer
# 5      0.000           6  Jimcramer
# 6      0.370           7  Jimcramer
# 7      0.140           8  Jimcramer
# 8      0.221           9  Jimcramer
# 9      0.149          10  Jimcramer
# 10     0.000          11  Jimcramer
# 11     0.457          12  Jimcramer
# 12     0.172          13  Jimcramer
# 13     0.000          14  Jimcramer
# 14     0.140          15  Jimcramer
# 15     0.242          16  Jimcramer
# 16     0.228          17  Jimcramer
# 17     0.000          18  Jimcramer
# 18     0.000          19  Jimcramer
# 19     0.000          20  Jimcramer
# 20     0.000          21  Jimcramer
# 21     0.000          22  Jimcramer
# 22     0.116          23  Jimcramer
# 23     0.000          24  Jimcramer
# 24     0.363          25  Jimcramer
# 25     0.483          26  Jimcramer
# 26     0.000          27  Jimcramer
# 27     0.512          28  Jimcramer
# 28     0.000          29  Jimcramer
# 29     0.000          30  Jimcramer
# 30     0.186          31  Jimcramer
# 31     0.824          32  Jimcramer
# 32     0.172          33  Jimcramer
# 33     0.000          34  Jimcramer
# 34     0.000          35  Jimcramer
# 35     0.000          36  Jimcramer
# 36     0.213          37  Jimcramer
# 37     0.000          38  Jimcramer
# 38     0.000          39  Jimcramer
# 39     0.185          40  Jimcramer
# 40     0.000          41  Jimcramer
# 41     0.000          42  Jimcramer
# 42     0.155          43  Jimcramer
# 43     0.000          44  Jimcramer
# 44     0.000          45  Jimcramer
# 45     0.000          46  Jimcramer
# 46     0.000          47  Jimcramer
# 47     0.000          48  Jimcramer
# 48     0.000          49  Jimcramer
# 49     0.000          50  Jimcramer

# %%
sentiment_tweets['Date'] = sentiment_tweets['Date'].map(lambda x: x.split(' '))

# %%
sentiment_tweets['Date'] = sentiment_tweets['Date'].map(lambda x: x[0:3])

# %%
sentiment_tweets = sentiment_tweets[['Date','User','Followers','Compound','Positive','Neutral','Negative']]

# %%
sentiment_tweets_clean = sentiment_tweets.loc[sentiment_tweets['Compound']!= 0]
sentiment_tweets_clean.head()
# Out:
#              Date       User  Followers  Compound  Positive  Neutral  Negative
# 0  [Thu, Dec, 14]  Jimcramer    1053721    0.5707     0.251    0.000     0.749
# 3  [Thu, Dec, 14]  Jimcramer    1053721    0.6369     0.154    0.000     0.846
# 4  [Thu, Dec, 14]  Jimcramer    1053721    0.3818     0.206    0.107     0.687
# 6  [Thu, Dec, 14]  Jimcramer    1053721    0.7901     0.370    0.069     0.561
# 7  [Thu, Dec, 14]  Jimcramer    1053721    0.1531     0.140    0.105     0.756

# %%
sentiment_tweets_clean.to_csv('Twitter_TargetUser_data1213.csv',header=True,sep=',', index= False)

# %%
sentiment_filtered = sentiment_tweets[['Compound','Tweets Ago','User']]

# %%
palette_color = sns.color_palette()
twitter_scatter = sns.lmplot(x='Tweets Ago', y='Compound', 
                             data=sentiment_filtered,hue='User' ,
                             palette=palette_color
                            ,fit_reg= False, legend = False)
plt.ylim(ymax = 1)
plt.gca().invert_xaxis()
plt.legend(fontsize="small", mode="Expanded", 
                  numpoints=1, scatterpoints=1, 
                  loc="upper left", bbox_to_anchor=(1,1), title="Media Sources", 
                  labelspacing=0.5)
plt.ylabel('Tweet Polarity')
plt.grid(True)
plt.show()

# %%
df_bar_grouping = sentiment_filtered.groupby(['User']).mean()['Compound']

# %%
sns.set_style(style='dark')

bar_tweet = sns.barplot(x='User', y='Compound', data=sentiment_filtered)
plt.title('Overal Media Sentiment based on Twitter (last 100 tweets) ')
plt.xlabel('Twitter Name')
plt.ylim(ymax = .03)
plt.ylim(ymin = -.15)
plt.show()
