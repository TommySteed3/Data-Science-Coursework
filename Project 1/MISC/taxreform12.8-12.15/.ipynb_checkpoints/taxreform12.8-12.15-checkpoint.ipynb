# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns
import codecs, json, time, re, tweepy
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
with codecs.open('taxreform9to12.json', 'r', 'utf-8') as f:
    tweets = json.load(f, encoding='utf-8')

# %%
tweet_df = pd.DataFrame(tweets)
print(tweet_df["timestamp"].nunique())
tweet_df.info()
# Out:
# 206241
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221931 entries, 0 to 221930
# Data columns (total 9 columns):
# fullname     221931 non-null object
# id           221931 non-null object
# likes        221931 non-null object
# replies      221931 non-null object
# retweets     221931 non-null object
# text         221931 non-null object
# timestamp    221931 non-null object
# url          221931 non-null object
# user         221931 non-null object
# dtypes: object(9)
# memory usage: 15.2+ MB

# %%
Date = []
Time = []
for time in tweet_df["timestamp"]:
    Date.append(datetime.strptime(time.split("T")[0], "%Y-%m-%d"))
    print('.', end='')

tweet_df["Date"] = Date
tweet_df.head()
# Out:
# ......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# ...

# %%
tweet_df = tweet_df.loc[:,["user","text","Date"]]
tweet_df.head()
# Out:
#              user                                               text  \
# 0    robertemilem  So-called #TaxReform will make us all regret t...
# 1       CrippledU  Why shld the 60% incorporated Doctors pay less...
# 2       iampeterk  Hey.. @JustinTrudeau ...you should read this a...
# 3  VeronicaBaldwi  @HedyFry Approve @liberal_party Tax changes. C...
# 4  VeronicaBaldwi  .@CPC_HQ @AndrewScheer Approve of closing tax ...
#
#         Date
# 0 2017-09-11
# 1 2017-09-11
# 2 2017-09-11
# 3 2017-09-11
# 4 2017-09-11

# %%
compound_list = []

for tweet in tweet_df["text"]:
    compound = analyzer.polarity_scores(tweet)["compound"]
    compound_list.append(compound)

tweet_df["Compound"] = compound_list
tweet_df.head()
# Out:
#              user                                               text  \
# 0    robertemilem  So-called #TaxReform will make us all regret t...
# 1       CrippledU  Why shld the 60% incorporated Doctors pay less...
# 2       iampeterk  Hey.. @JustinTrudeau ...you should read this a...
# 3  VeronicaBaldwi  @HedyFry Approve @liberal_party Tax changes. C...
# 4  VeronicaBaldwi  .@CPC_HQ @AndrewScheer Approve of closing tax ...
#
#         Date  Compound
# 0 2017-09-11   -0.4215
# 1 2017-09-11   -0.1027
# 2 2017-09-11    0.0000
# 3 2017-09-11    0.6177
# 4 2017-09-11    0.1585

# %%
tweet_df_mean = pd.DataFrame(tweet_df.groupby(["Date"])["Compound"].mean()).reset_index()
tweet_df_mean.head()
# Out:
#         Date  Compound
# 0 2017-09-11  0.064516
# 1 2017-09-12  0.092184
# 2 2017-09-13  0.083724
# 3 2017-09-14  0.108868
# 4 2017-09-15  0.073877

# %% [markdown]
# # PART II: MARKET ANALYSIS

# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import warnings
#warnings.filterwarnings('ignore')

# %%
# We would like all available data from MM/DD/YYYY until MM/DD/YYYY.
start_date = tweet_df_mean["Date"].min().strftime('%Y-%m-%d')
end_date = tweet_df_mean["Date"].max().strftime('%Y-%m-%d')
print("Start date is: "+start_date)
print("End date is: "+end_date)
# Out:
# Start date is: 2017-09-11
# End date is: 2017-12-10

# %%
# Define the instruments to download. We would like to see Apple, Microsoft and the S&P500 index.
tickers = ['^DJI', '^GSPC'] #, '^IXIC']

# Define which online source one should use
data_source = 'yahoo'

# User pandas_reader.data.DataReader to load the desired data. As simple as that.
panel_data = data.DataReader(tickers, data_source, start_date, end_date)

# %%
# Getting just the adjusted closing prices. This will return a Pandas DataFrame
# The index in this DataFrame is the major index of the panel_data.
adj_close = panel_data.ix['Adj Close']

# Getting all weekdays between MM/DD/YYYY and MM/DD/YYYY
all_weekdays = pd.date_range(start=start_date, end=end_date, freq='B')

# How do we align the existing prices in adj_close with our new set of dates?
# All we need to do is reindex close using all_weekdays as the new index
adj_close = adj_close.reindex(all_weekdays)

# Reindexing will insert missing values (NaN) for the dates that were not present
# in the original set. To cope with this, we can fill the missing by replacing them
# with the latest available price for each instrument.
adj_close = adj_close.fillna(method='ffill')

adj_close.head()
# Out:
#                     ^DJI        ^GSPC
# 2017-09-11  22057.369141  2488.110107
# 2017-09-12  22118.859375  2496.479980
# 2017-09-13  22158.179688  2498.370117
# 2017-09-14  22203.480469  2495.620117
# 2017-09-15  22268.339844  2500.229980

# %%
adj_close["^DJI Returns"] = ""
adj_close["^GSPC Returns"] = ""
# adj_close["^IXIC Returns"] = ""
adj_close.head()
# Out:
#                     ^DJI        ^GSPC ^DJI Returns ^GSPC Returns
# 2017-09-11  22057.369141  2488.110107
# 2017-09-12  22118.859375  2496.479980
# 2017-09-13  22158.179688  2498.370117
# 2017-09-14  22203.480469  2495.620117
# 2017-09-15  22268.339844  2500.229980

# %%
adj_close.index.name = "Date"
adj_close = adj_close.reset_index()

# %%
# Set initial return value as this is the start
adj_close.set_value(0, "^DJI Returns", 0)
adj_close.set_value(0, "^GSPC Returns", 0)
# adj_close.set_value(0, "^IXIC Returns", 0)
i = 0

# Scaling Factor for comparison with Twitter
m = 20

# Iterate through each row and calculate the daily returns
for index, row in adj_close.iterrows():
    if index==0:
        print("1st row skipped")
    else:
        try:
            # Calculate the daily returns
            dji_returns = ((row["^DJI"]/adj_close["^DJI"][i])-1)*m
            gspc_returns = ((row["^GSPC"]/adj_close["^GSPC"][i])-1)*m
#             ixic_returns = ((row["^IXIC"]/adj_close["^IXIC"][i])-1)*m
            
            # Set return values to appropriate index
            adj_close.set_value(index, "^DJI Returns", dji_returns)
            adj_close.set_value(index, "^GSPC Returns", gspc_returns)
#             adj_close.set_value(index, "^IXIC Returns", ixic_returns)
            i += 1
            print(".", end="")
        except:
            print("This doesn't work. Please try again")

adj_close_returns = adj_close.set_index("Date")
adj_close_returns.head()
# Out:
# 1st row skipped
# ................................................................
#                     ^DJI        ^GSPC ^DJI Returns ^GSPC Returns
# Date
# 2017-09-11  22057.369141  2488.110107            0             0
# 2017-09-12  22118.859375  2496.479980    0.0557548      0.067279
# 2017-09-13  22158.179688  2498.370117    0.0355537     0.0151424
# 2017-09-14  22203.480469  2495.620117    0.0408885    -0.0220144
# 2017-09-15  22268.339844  2500.229980    0.0584227     0.0369436

# %%
adj_close.describe()
# Out:
#                ^DJI        ^GSPC
# count     65.000000    65.000000
# mean   23150.168480  2564.247247
# std      625.085111    43.936338
# min    22057.369141  2488.110107
# 25%    22641.669922  2534.580078
# 50%    23329.460938  2564.979980
# 75%    23526.179688  2590.639893
# max    24329.160156  2651.500000

# %% [markdown]
# #### PLOT

# %%
width = 15
height = 10

# Get the DJI time series. This now returns a Pandas Series object indexed by date.
dji = adj_close_returns.ix[:, '^DJI Returns']
gspc = adj_close_returns.ix[:, '^GSPC Returns']

# Calculate the 20 and 100 days moving averages of the closing prices
short_rolling_dji = dji.rolling(window=5).mean()
# long_rolling_dji = dji.rolling(window=100).mean()

# short_rolling_gspc = gspc.rolling(window=20).mean()
# long_rolling_gspc = gspc.rolling(window=100).mean()

# ixic = adj_close_returns.ix[:, '^IXIC Returns']

# Plot everything by leveraging the very powerful matplotlib package
fig = plt.figure(figsize=(width,height))
ax = fig.add_subplot(1,1,1)
ax.plot(dji.index, dji, label='DJI Returns', color = "pink")#, color = "red")

ax.plot(tweet_df_mean["Date"], tweet_df_mean['Compound']*0, alpha=0.75, color = "black", label = '')
# ax.plot(gspc.index, gspc, label='GSPC Returns')#, color = "green")
# ax.plot(ixic.index, ixic, label='IXIC Returns', color = "green")
ax.plot(tweet_df_mean["Date"], tweet_df_mean['Compound'], label='Tweet', color = "blue")#, color = "blue")
ax.plot(short_rolling_dji.index, short_rolling_dji, label='5 days rolling', color = "green")
# ax.plot(long_rolling_dji.index, long_rolling_dji, label='100 days rolling')

# ax.plot(short_rolling_gspc.index, short_rolling_gspc, label='20 days rolling')
# ax.plot(long_rolling_gspc.index, long_rolling_gspc, label='100 days rolling')

ax.set_xlabel('Date')
ax.set_ylabel('Normalized Returns & Sentiment')
ax.set_title('#TaxReform Sentiment vs DOW Returns')
ax.legend()

plt.savefig('taxreform-'+start_date+"to"+end_date)
plt.show()
